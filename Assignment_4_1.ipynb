# %%
################################

# Student: Justin Hudson
# Instructor: Kaleab Gorfu
# CS 121: Python for DS and ML
# Date: 19/04/2026

################################

import numpy as np

np.linspace(0.0, 5.0, num=15)

# %%
# !jupyter nbconvert --to script --no-prompt --TagRemovePreprocessor.remove_cell_tags="['remove']" Assignment_4_1.ipynb
