# %%
################################

# Student: Justin Hudson
# Instructor: Kaleab Gorfu
# CS 121: Python for DS and ML
# Date: 14/04/2026

################################

import numpy as np

np.arange(1, 101).reshape(20, 5)

# %%
# !jupyter nbconvert --to script --no-prompt --TagRemovePreprocessor.remove_cell_tags="['remove']" Assignment_4_2.ipynb
